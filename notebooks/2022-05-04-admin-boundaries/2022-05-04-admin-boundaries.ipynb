# %% [markdown]
# The purpose of this notebook is to add Thailand admin boundaries to an already existing dataset (CSV file). This logic is already integrated into the main data generation script though, so if you generated data using that, there should be no need to run this notebook.

# %% [markdown]
# # Imports

# %%
import sys
sys.path.append("../../")

import geopandas as gpd
import pandas as pd

from src.config import settings

# %% [markdown]
# # Inputs

# %%
# Path to the TH Admin Bounds shapefile.
# The file has to be placed in the data folder in the project root.
TH_ADM3_SHP = settings.DATA_DIR / "th_boundaries/adm3/tha_admbnda_adm3_rtsd_20220121.shp"

# Path to the CSV file you want to add admin boundaries to.
STATIONS_CSV = settings.DATA_DIR/"2022-04-29-base-table-air4thai.csv"

# Where to save the final augmented CSV.
OUTPUT_CSV = settings.DATA_DIR/"2022-04-29-base-table-air4thai-with-adm3.csv"

# %% [markdown]
# # TH Admin Bounds
#
# The admin bounds file is taken from the [Humanitarian Data Exchange](https://data.humdata.org/dataset/cod-ab-tha) website.
#
# Here we're using the most granular data available, which are the admin level 3 boundaries. But the Shapefile also contains info all the way from admin level 0 to 3.

# %%
th_adm3_gdf = gpd.read_file(TH_ADM3_SHP)
th_adm3_gdf.head()
# Out:
#    Shape_Leng  Shape_Area                   ADM3_EN          ADM3_TH  \
# 0    0.047699    0.000128  Phraborom Maharatchawang  พระบรมมหาราชวัง
# 1    0.033550    0.000061       Wang Burapha Phirom   วังบูรพาภิรมย์
# 2    0.017289    0.000018          Wat Ratchabophit       วัดราชบพิธ
# 3    0.019046    0.000019                Samran Rat      สำราญราษฎร์
# 4    0.015232    0.000013          San Chaopho Suea   ศาลเจ้าพ่อเสือ
#
#   ADM3_PCODE ADM3_REF ADM3ALT1EN ADM3ALT2EN ADM3ALT1TH ADM3ALT2TH  ...  \
# 0   TH100101     None       None       None       None       None  ...
# 1   TH100102     None       None       None       None       None  ...
# 2   TH100103     None       None       None       None       None  ...
# 3   TH100104     None       None       None       None       None  ...
# 4   TH100105     None       None       None       None       None  ...
#
#    ADM1_EN        ADM1_TH ADM1_PCODE   ADM0_EN    ADM0_TH ADM0_PCODE  \
# 0  Bangkok  กรุงเทพมหานคร       TH10  Thailand  ประเทศไทย         TH
# 1  Bangkok  กรุงเทพมหานคร       TH10  Thailand  ประเทศไทย         TH
# 2  Bangkok  กรุงเทพมหานคร       TH10  Thailand  ประเทศไทย         TH
# 3  Bangkok  กรุงเทพมหานคร       TH10  Thailand  ประเทศไทย         TH
# 4  Bangkok  กรุงเทพมหานคร       TH10  Thailand  ประเทศไทย         TH
#
#          date     validOn validTo  \
# 0  2019-02-18  2022-01-22    None
# 1  2019-02-18  2022-01-22    None
# 2  2019-02-18  2022-01-22    None
# 3  2019-02-18  2022-01-22    None
# 4  2019-02-18  2022-01-22    None
#
#                                             geometry
# 0  POLYGON ((100.49453 13.75759, 100.49486 13.757...
# 1  POLYGON ((100.50131 13.74800, 100.50170 13.747...
# 2  POLYGON ((100.50140 13.74817, 100.50131 13.748...
# 3  POLYGON ((100.50554 13.75378, 100.50516 13.752...
# 4  POLYGON ((100.49875 13.75560, 100.49873 13.755...
#
# [5 rows x 23 columns]

# %% [markdown]
# # Identify the admin bounds for stations
#
# In this notebook, we're identifying the admin bounds for an already existing dataset we're using for ML modelling.

# %%
stations_df = pd.read_csv(STATIONS_CSV)
stations_df.head()
# Out:
#          date  number station_code              station_location  \
# 0  2021-01-01     1.0          02T  แขวงหิรัญรูจี เขตธนบุรี กทม.
# 1  2021-01-02     1.0          02T  แขวงหิรัญรูจี เขตธนบุรี กทม.
# 2  2021-01-03     1.0          02T  แขวงหิรัญรูจี เขตธนบุรี กทม.
# 3  2021-01-04     1.0          02T  แขวงหิรัญรูจี เขตธนบุรี กทม.
# 4  2021-01-05     1.0          02T  แขวงหิรัญรูจี เขตธนบุรี กทม.
#
#                     station_description  \
# 0  มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา
# 1  มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา
# 2  มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา
# 3  มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา
# 4  มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา
#
#                                      station_address   latitude   longitude  \
# 0  มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา, แขวงหิรั...  13.732218  100.490298
# 1  มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา, แขวงหิรั...  13.732218  100.490298
# 2  มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา, แขวงหิรั...  13.732218  100.490298
# 3  มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา, แขวงหิรั...  13.732218  100.490298
# 4  มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา, แขวงหิรั...  13.732218  100.490298
#
#                                  en_station_location  \
# 0  Hiran Ruchi Subdistrict, Thon Buri District, B...
# 1  Hiran Ruchi Subdistrict, Thon Buri District, B...
# 2  Hiran Ruchi Subdistrict, Thon Buri District, B...
# 3  Hiran Ruchi Subdistrict, Thon Buri District, B...
# 4  Hiran Ruchi Subdistrict, Thon Buri District, B...
#
#                        en_station_description  ...  \
# 0  Ban Somdej Chao Phraya Rajabhat University  ...
# 1  Ban Somdej Chao Phraya Rajabhat University  ...
# 2  Ban Somdej Chao Phraya Rajabhat University  ...
# 3  Ban Somdej Chao Phraya Rajabhat University  ...
# 4  Ban Somdej Chao Phraya Rajabhat University  ...
#
#   v_component_of_wind_10m_min  v_component_of_wind_10m_median  \
# 0                   -3.282547                       -2.556892
# 1                   -2.775949                       -2.416763
# 2                   -3.097609                       -2.379429
# 3                   -2.963577                       -2.505539
# 4                   -2.359756                       -1.022918
#
#    v_component_of_wind_10m_max  surface_pressure_mean  surface_pressure_min  \
# 0                    -1.635864          101386.687174         101167.296875
# 1                    -1.823283          101275.681641         101084.816406
# 2                    -1.599380          101148.800944         100933.792969
# 3                    -2.123150          101150.715658         100932.554688
# 4                     1.458656          101086.567546         100909.343750
#
#    surface_pressure_median  surface_pressure_max  total_precipitation_daily  \
# 0            101366.146484         101646.625000               0.000000e+00
# 1            101245.742188         101564.906250               0.000000e+00
# 2            101133.964844         101385.933594               8.583069e-07
# 3            101143.691406         101400.675781               8.523463e-07
# 4            101066.410156         101330.437500               8.523463e-07
#
#    mean_precipitation_hourly  pm2.5
# 0               0.000000e+00   27.0
# 1               0.000000e+00   32.0
# 2               3.576279e-08   46.0
# 3               3.551443e-08   39.0
# 4               3.551443e-08   50.0
#
# [5 rows x 59 columns]

# %% [markdown]
# Before doing a spatial join with the admin bounds, we have to convert the stations DataFrame into a GeoDataFrame.

# %%
stations_gdf = gpd.GeoDataFrame(
    stations_df,
    geometry = gpd.points_from_xy(stations_df["longitude"], stations_df["latitude"]),
    crs="EPSG:4326"
)

stations_gdf.head()
# Out:
#          date  number station_code              station_location  \
# 0  2021-01-01     1.0          02T  แขวงหิรัญรูจี เขตธนบุรี กทม.
# 1  2021-01-02     1.0          02T  แขวงหิรัญรูจี เขตธนบุรี กทม.
# 2  2021-01-03     1.0          02T  แขวงหิรัญรูจี เขตธนบุรี กทม.
# 3  2021-01-04     1.0          02T  แขวงหิรัญรูจี เขตธนบุรี กทม.
# 4  2021-01-05     1.0          02T  แขวงหิรัญรูจี เขตธนบุรี กทม.
#
#                     station_description  \
# 0  มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา
# 1  มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา
# 2  มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา
# 3  มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา
# 4  มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา
#
#                                      station_address   latitude   longitude  \
# 0  มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา, แขวงหิรั...  13.732218  100.490298
# 1  มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา, แขวงหิรั...  13.732218  100.490298
# 2  มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา, แขวงหิรั...  13.732218  100.490298
# 3  มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา, แขวงหิรั...  13.732218  100.490298
# 4  มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา, แขวงหิรั...  13.732218  100.490298
#
#                                  en_station_location  \
# 0  Hiran Ruchi Subdistrict, Thon Buri District, B...
# 1  Hiran Ruchi Subdistrict, Thon Buri District, B...
# 2  Hiran Ruchi Subdistrict, Thon Buri District, B...
# 3  Hiran Ruchi Subdistrict, Thon Buri District, B...
# 4  Hiran Ruchi Subdistrict, Thon Buri District, B...
#
#                        en_station_description  ...  \
# 0  Ban Somdej Chao Phraya Rajabhat University  ...
# 1  Ban Somdej Chao Phraya Rajabhat University  ...
# 2  Ban Somdej Chao Phraya Rajabhat University  ...
# 3  Ban Somdej Chao Phraya Rajabhat University  ...
# 4  Ban Somdej Chao Phraya Rajabhat University  ...
#
#   v_component_of_wind_10m_median  v_component_of_wind_10m_max  \
# 0                      -2.556892                    -1.635864
# 1                      -2.416763                    -1.823283
# 2                      -2.379429                    -1.599380
# 3                      -2.505539                    -2.123150
# 4                      -1.022918                     1.458656
#
#    surface_pressure_mean  surface_pressure_min  surface_pressure_median  \
# 0          101386.687174         101167.296875            101366.146484
# 1          101275.681641         101084.816406            101245.742188
# 2          101148.800944         100933.792969            101133.964844
# 3          101150.715658         100932.554688            101143.691406
# 4          101086.567546         100909.343750            101066.410156
#
#    surface_pressure_max  total_precipitation_daily  mean_precipitation_hourly  \
# 0         101646.625000               0.000000e+00               0.000000e+00
# 1         101564.906250               0.000000e+00               0.000000e+00
# 2         101385.933594               8.583069e-07               3.576279e-08
# 3         101400.675781               8.523463e-07               3.551443e-08
# 4         101330.437500               8.523463e-07               3.551443e-08
#
#    pm2.5                    geometry
# 0   27.0  POINT (100.49030 13.73222)
# 1   32.0  POINT (100.49030 13.73222)
# 2   46.0  POINT (100.49030 13.73222)
# 3   39.0  POINT (100.49030 13.73222)
# 4   50.0  POINT (100.49030 13.73222)
#
# [5 rows x 60 columns]

# %% [markdown]
# We then perform the spatial join. For each station, we're interested in finding which admin bounds they fall under. This line of code finds where the station's coordinates are "within" which admin boundary.

# %%
# First, we want to retain only the unique columns in the right GDF to avoid duplicate columns (and consequent column renames).
cols_unique_to_th_adm3 = th_adm3_gdf.columns.difference(stations_gdf.columns).tolist() + ["geometry"]
th_adm3_gdf = th_adm3_gdf[cols_unique_to_th_adm3]

# Perform the actual spatial join
joined_gdf = gpd.sjoin(stations_gdf, th_adm3_gdf, predicate="within", how="left")

# Drop unnecessary columns generated by the sjoin
joined_gdf.drop(["index_right"], axis=1, inplace=True)

# Sanity check the output
print(joined_gdf.columns)
joined_gdf.head()
# Out:
# Index(['date', 'number', 'station_code', 'station_location',
#        'station_description', 'station_address', 'latitude', 'longitude',
#        'en_station_location', 'en_station_description', 'en_station_address',
#        'total_population', 'AAI_mean', 'AAI_min', 'AAI_max', 'AAI_median',
#        'CAMS_AOD_055_mean', 'CAMS_AOD_055_min', 'CAMS_AOD_055_max',
#        'CAMS_AOD_055_median', 'AOD_047_mean', 'AOD_047_min', 'AOD_047_max',
#        'AOD_047_median', 'AOD_055_mean', 'AOD_055_min', 'AOD_055_max',
#        'AOD_055_median', 'NDVI_mean', 'NDVI_min', 'NDVI_max', 'NDVI_median',
#        'EVI_mean', 'EVI_min', 'EVI_max', 'EVI_median',
#        'dewpoint_temperature_2m_mean', 'dewpoint_temperature_2m_min',
#        'dewpoint_temperature_2m_median', 'dewpoint_temperature_2m_max',
#        'temperature_2m_mean', 'temperature_2m_min', 'temperature_2m_median',
#        'temperature_2m_max', 'u_component_of_wind_10m_mean',
#        'u_component_of_wind_10m_min', 'u_component_of_wind_10m_median',
#        'u_component_of_wind_10m_max', 'v_component_of_wind_10m_mean',
#        'v_component_of_wind_10m_min', 'v_component_of_wind_10m_median',
#        'v_component_of_wind_10m_max', 'surface_pressure_mean',
#        'surface_pressure_min', 'surface_pressure_median',
#        'surface_pressure_max', 'total_precipitation_daily',
#        'mean_precipitation_hourly', 'pm2.5', 'geometry', 'ADM0_EN',
#        'ADM0_PCODE', 'ADM0_TH', 'ADM1_EN', 'ADM1_PCODE', 'ADM1_TH', 'ADM2_EN',
#        'ADM2_PCODE', 'ADM2_TH', 'ADM3ALT1EN', 'ADM3ALT1TH', 'ADM3ALT2EN',
#        'ADM3ALT2TH', 'ADM3_EN', 'ADM3_PCODE', 'ADM3_REF', 'ADM3_TH',
#        'Shape_Area', 'Shape_Leng', 'validOn', 'validTo'],
#       dtype='object')
#          date  number station_code              station_location  \
# 0  2021-01-01     1.0          02T  แขวงหิรัญรูจี เขตธนบุรี กทม.
# 1  2021-01-02     1.0          02T  แขวงหิรัญรูจี เขตธนบุรี กทม.
# 2  2021-01-03     1.0          02T  แขวงหิรัญรูจี เขตธนบุรี กทม.
# 3  2021-01-04     1.0          02T  แขวงหิรัญรูจี เขตธนบุรี กทม.
# 4  2021-01-05     1.0          02T  แขวงหิรัญรูจี เขตธนบุรี กทม.
#
#                     station_description  \
# 0  มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา
# 1  มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา
# 2  มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา
# 3  มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา
# 4  มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา
#
#                                      station_address   latitude   longitude  \
# 0  มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา, แขวงหิรั...  13.732218  100.490298
# 1  มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา, แขวงหิรั...  13.732218  100.490298
# 2  มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา, แขวงหิรั...  13.732218  100.490298
# 3  มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา, แขวงหิรั...  13.732218  100.490298
# 4  มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา, แขวงหิรั...  13.732218  100.490298
#
#                                  en_station_location  \
# 0  Hiran Ruchi Subdistrict, Thon Buri District, B...
# 1  Hiran Ruchi Subdistrict, Thon Buri District, B...
# 2  Hiran Ruchi Subdistrict, Thon Buri District, B...
# 3  Hiran Ruchi Subdistrict, Thon Buri District, B...
# 4  Hiran Ruchi Subdistrict, Thon Buri District, B...
#
#                        en_station_description  ... ADM3ALT2EN  ADM3ALT2TH  \
# 0  Ban Somdej Chao Phraya Rajabhat University  ...       None        None
# 1  Ban Somdej Chao Phraya Rajabhat University  ...       None        None
# 2  Ban Somdej Chao Phraya Rajabhat University  ...       None        None
# 3  Ban Somdej Chao Phraya Rajabhat University  ...       None        None
# 4  Ban Somdej Chao Phraya Rajabhat University  ...       None        None
#
#       ADM3_EN  ADM3_PCODE  ADM3_REF    ADM3_TH  Shape_Area  Shape_Leng  \
# 0  Hiranruchi    TH101502      None  หิรัญรูจี    0.000054    0.029718
# 1  Hiranruchi    TH101502      None  หิรัญรูจี    0.000054    0.029718
# 2  Hiranruchi    TH101502      None  หิรัญรูจี    0.000054    0.029718
# 3  Hiranruchi    TH101502      None  หิรัญรูจี    0.000054    0.029718
# 4  Hiranruchi    TH101502      None  หิรัญรูจี    0.000054    0.029718
#
#       validOn  validTo
# 0  2022-01-22     None
# 1  2022-01-22     None
# 2  2022-01-22     None
# 3  2022-01-22     None
# 4  2022-01-22     None
#
# [5 rows x 81 columns]

# %% [markdown]
# Finally, we save the output to a CSV file.

# %%
joined_gdf.to_csv(OUTPUT_CSV, index=False)
