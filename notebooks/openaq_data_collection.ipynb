# %% [markdown]
# # OpenAQ Thailand PM 2.5 Data Collection

# %%
import pandas as pd 
import numpy as np 
import json
import requests
import time

# %%
# Set server URL as global variable.
server_url = 'https://u50g7n0cbj.execute-api.us-east-1.amazonaws.com/v2' # working as of May 27, 2022

# %% [markdown]
# ## Functions

# %%
def construct_url(server_url, method, parameters):

    url_params = ''

    # Construct URL string for all parameters
    
    for index, value in enumerate(parameters):
        
        # This if clause just catches the last parameter (shouldn't have a succeeding &)
        if index == len(parameters)-1:
          param = value+'='+str(parameters[value])
        else:
          param = value+'='+str(parameters[value])+'&'

        # Append to URL parameters string
        url_params = url_params+param

    url = server_url+'/'+method+'?'+url_params
    url = url.replace(" ","%20")

    return(url)

# %%
def openaq_get(url):

    # API call
    response = requests.get(url)

    # Get results specifically
    data = response.json()['results']

    # Convert json output to DataFrame
    df = pd.json_normalize(data)

    return df

# %%
def get_measurements(country_id, start_date, end_date, parameter='pm25', sensor_type=None, limit=10000, include_mobile=False):

    method = 'measurements'

    parameters = {
        "date_from": start_date,
        "date_to": end_date,
        "has_geo": True,
        "parameter": parameter,
        "country_id": country_id,
        "limit": limit,
        "isMobile": include_mobile
    }

    # If sensor type is explicitly indicated
    if sensor_type:
        parameters['sensorType'] = sensor_type

    url = construct_url(server_url, method, parameters)
    df = openaq_get(url)

    return df

# %% [markdown]
# ## Data Collection

# %%
# Set date range
date_range = pd.date_range('2021-01-01','2021-12-31')

# Create base table
openaq_df = pd.DataFrame()

# Iterate through date range
for d in date_range:
    
    start_date = d.date()
    end_date = pd.to_datetime(d) + pd.Timedelta(days=1)

    # Indicator for when data collection for a new month starts
    if d.day == 1:
        print(f'Collecting data for Month {start_date.month}...')
    
    t = 5
    for attempt in range(1,100):
        try:
            # Call API
            temp_df = get_measurements('TH', start_date, end_date)
        except KeyError:
            print(f'API limit exceeded for {start_date}. Trying again in {t} seconds... Retry attempt: {attempt}')
            time.sleep(t)
            print(f'Trying again for {start_date}.')
            t += 5
        else:
            break
    else:
        print(f'Error collecting data for {start_date}. Skipping to next date...')

    # Add to base table
    openaq_df = pd.concat([openaq_df, temp_df])
    
    # When the month is finished, sleep for 3 mins --workaround for API limits
    if start_date.month != end_date.month:
        print(f'Month {start_date.month} done. Please wait for the next month to start... Time: 3 mins')
        time.sleep(180)
    

print('Data collection complete.')
openaq_df
# Out:
# Collecting data for Month 1...
# API limit exceeded for 2021-01-22. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-01-22.
# API limit exceeded for 2021-01-23. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-01-23.
# API limit exceeded for 2021-01-23. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-01-23.
# API limit exceeded for 2021-01-24. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-01-24.
# API limit exceeded for 2021-01-24. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-01-24.
# API limit exceeded for 2021-01-25. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-01-25.
# API limit exceeded for 2021-01-26. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-01-26.
# API limit exceeded for 2021-01-26. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-01-26.
# API limit exceeded for 2021-01-27. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-01-27.
# API limit exceeded for 2021-01-27. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-01-27.
# API limit exceeded for 2021-01-28. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-01-28.
# API limit exceeded for 2021-01-29. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-01-29.
# API limit exceeded for 2021-01-29. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-01-29.
# API limit exceeded for 2021-01-30. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-01-30.
# API limit exceeded for 2021-01-31. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-01-31.
# API limit exceeded for 2021-01-31. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-01-31.
# Month 1 done. Please wait for the next month to start... Time: 3 mins
# Collecting data for Month 2...
# API limit exceeded for 2021-02-01. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-02-01.
# API limit exceeded for 2021-02-01. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-02-01.
# API limit exceeded for 2021-02-02. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-02-02.
# API limit exceeded for 2021-02-02. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-02-02.
# API limit exceeded for 2021-02-04. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-02-04.
# API limit exceeded for 2021-02-04. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-02-04.
# API limit exceeded for 2021-02-05. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-02-05.
# API limit exceeded for 2021-02-05. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-02-05.
# API limit exceeded for 2021-02-06. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-02-06.
# API limit exceeded for 2021-02-07. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-02-07.
# API limit exceeded for 2021-02-07. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-02-07.
# API limit exceeded for 2021-02-08. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-02-08.
# API limit exceeded for 2021-02-09. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-02-09.
# API limit exceeded for 2021-02-09. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-02-09.
# API limit exceeded for 2021-02-10. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-02-10.
# API limit exceeded for 2021-02-11. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-02-11.
# API limit exceeded for 2021-02-12. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-02-12.
# API limit exceeded for 2021-02-12. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-02-12.
# API limit exceeded for 2021-02-14. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-02-14.
# API limit exceeded for 2021-02-16. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-02-16.
# API limit exceeded for 2021-02-16. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-02-16.
# API limit exceeded for 2021-02-16. Trying again in 15 seconds... Retry attempt: 3
# Trying again for 2021-02-16.
# API limit exceeded for 2021-02-17. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-02-17.
# API limit exceeded for 2021-02-18. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-02-18.
# API limit exceeded for 2021-02-18. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-02-18.
# API limit exceeded for 2021-02-19. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-02-19.
# API limit exceeded for 2021-02-20. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-02-20.
# API limit exceeded for 2021-02-21. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-02-21.
# API limit exceeded for 2021-02-21. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-02-21.
# API limit exceeded for 2021-02-22. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-02-22.
# API limit exceeded for 2021-02-22. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-02-22.
# API limit exceeded for 2021-02-24. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-02-24.
# API limit exceeded for 2021-02-25. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-02-25.
# API limit exceeded for 2021-02-25. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-02-25.
# API limit exceeded for 2021-02-28. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-02-28.
# Month 2 done. Please wait for the next month to start... Time: 3 mins
# Collecting data for Month 3...
# API limit exceeded for 2021-03-01. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-03-01.
# API limit exceeded for 2021-03-02. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-03-02.
# API limit exceeded for 2021-03-02. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-03-02.
# API limit exceeded for 2021-03-03. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-03-03.
# API limit exceeded for 2021-03-03. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-03-03.
# API limit exceeded for 2021-03-03. Trying again in 15 seconds... Retry attempt: 3
# Trying again for 2021-03-03.
# API limit exceeded for 2021-03-03. Trying again in 20 seconds... Retry attempt: 4
# Trying again for 2021-03-03.
# API limit exceeded for 2021-03-04. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-03-04.
# API limit exceeded for 2021-03-05. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-03-05.
# API limit exceeded for 2021-03-05. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-03-05.
# API limit exceeded for 2021-03-06. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-03-06.
# API limit exceeded for 2021-03-06. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-03-06.
# API limit exceeded for 2021-03-09. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-03-09.
# API limit exceeded for 2021-03-11. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-03-11.
# API limit exceeded for 2021-03-12. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-03-12.
# API limit exceeded for 2021-03-13. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-03-13.
# API limit exceeded for 2021-03-13. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-03-13.
# API limit exceeded for 2021-03-14. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-03-14.
# API limit exceeded for 2021-03-14. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-03-14.
# API limit exceeded for 2021-03-15. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-03-15.
# API limit exceeded for 2021-03-16. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-03-16.
# API limit exceeded for 2021-03-18. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-03-18.
# API limit exceeded for 2021-03-23. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-03-23.
# API limit exceeded for 2021-03-24. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-03-24.
# API limit exceeded for 2021-03-24. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-03-24.
# API limit exceeded for 2021-03-25. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-03-25.
# API limit exceeded for 2021-03-26. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-03-26.
# API limit exceeded for 2021-03-27. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-03-27.
# API limit exceeded for 2021-03-28. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-03-28.
# API limit exceeded for 2021-03-29. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-03-29.
# Month 3 done. Please wait for the next month to start... Time: 3 mins
# Collecting data for Month 4...
# API limit exceeded for 2021-04-01. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-04-01.
# API limit exceeded for 2021-04-01. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-04-01.
# API limit exceeded for 2021-04-04. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-04-04.
# API limit exceeded for 2021-04-12. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-04-12.
# API limit exceeded for 2021-04-13. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-04-13.
# API limit exceeded for 2021-04-14. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-04-14.
# API limit exceeded for 2021-04-26. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-04-26.
# API limit exceeded for 2021-04-29. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-04-29.
# Month 4 done. Please wait for the next month to start... Time: 3 mins
# Collecting data for Month 5...
# API limit exceeded for 2021-05-07. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-05-07.
# API limit exceeded for 2021-05-09. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-05-09.
# API limit exceeded for 2021-05-10. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-05-10.
# API limit exceeded for 2021-05-11. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-05-11.
# API limit exceeded for 2021-05-13. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-05-13.
# API limit exceeded for 2021-05-14. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-05-14.
# API limit exceeded for 2021-05-22. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-05-22.
# API limit exceeded for 2021-05-25. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-05-25.
# API limit exceeded for 2021-05-26. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-05-26.
# API limit exceeded for 2021-05-26. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-05-26.
# API limit exceeded for 2021-05-28. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-05-28.
# API limit exceeded for 2021-05-28. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-05-28.
# API limit exceeded for 2021-05-30. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-05-30.
# API limit exceeded for 2021-05-31. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-05-31.
# Month 5 done. Please wait for the next month to start... Time: 3 mins
# Collecting data for Month 6...
# API limit exceeded for 2021-06-01. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-06-01.
# API limit exceeded for 2021-06-02. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-06-02.
# API limit exceeded for 2021-06-03. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-06-03.
# API limit exceeded for 2021-06-08. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-06-08.
# API limit exceeded for 2021-06-09. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-06-09.
# API limit exceeded for 2021-06-10. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-06-10.
# API limit exceeded for 2021-06-11. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-06-11.
# API limit exceeded for 2021-06-11. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-06-11.
# API limit exceeded for 2021-06-12. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-06-12.
# API limit exceeded for 2021-06-14. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-06-14.
# API limit exceeded for 2021-06-15. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-06-15.
# API limit exceeded for 2021-06-17. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-06-17.
# API limit exceeded for 2021-06-18. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-06-18.
# API limit exceeded for 2021-06-19. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-06-19.
# API limit exceeded for 2021-06-19. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-06-19.
# API limit exceeded for 2021-06-20. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-06-20.
# API limit exceeded for 2021-06-20. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-06-20.
# API limit exceeded for 2021-06-21. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-06-21.
# API limit exceeded for 2021-06-21. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-06-21.
# API limit exceeded for 2021-06-22. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-06-22.
# API limit exceeded for 2021-06-24. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-06-24.
# API limit exceeded for 2021-06-24. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-06-24.
# API limit exceeded for 2021-06-25. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-06-25.
# API limit exceeded for 2021-06-26. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-06-26.
# API limit exceeded for 2021-06-26. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-06-26.
# API limit exceeded for 2021-06-26. Trying again in 15 seconds... Retry attempt: 3
# Trying again for 2021-06-26.
# API limit exceeded for 2021-06-27. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-06-27.
# API limit exceeded for 2021-06-27. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-06-27.
# API limit exceeded for 2021-06-28. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-06-28.
# API limit exceeded for 2021-06-28. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-06-28.
# API limit exceeded for 2021-06-29. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-06-29.
# API limit exceeded for 2021-06-29. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-06-29.
# API limit exceeded for 2021-06-29. Trying again in 15 seconds... Retry attempt: 3
# Trying again for 2021-06-29.
# API limit exceeded for 2021-06-29. Trying again in 20 seconds... Retry attempt: 4
# Trying again for 2021-06-29.
# API limit exceeded for 2021-06-29. Trying again in 25 seconds... Retry attempt: 5
# Trying again for 2021-06-29.
# API limit exceeded for 2021-06-30. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-06-30.
# API limit exceeded for 2021-06-30. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-06-30.
# API limit exceeded for 2021-06-30. Trying again in 15 seconds... Retry attempt: 3
# Trying again for 2021-06-30.
# API limit exceeded for 2021-06-30. Trying again in 20 seconds... Retry attempt: 4
# Trying again for 2021-06-30.
# API limit exceeded for 2021-06-30. Trying again in 25 seconds... Retry attempt: 5
# Trying again for 2021-06-30.
# API limit exceeded for 2021-06-30. Trying again in 30 seconds... Retry attempt: 6
# Trying again for 2021-06-30.
# Month 6 done. Please wait for the next month to start... Time: 3 mins
# Collecting data for Month 7...
# API limit exceeded for 2021-07-01. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-07-01.
# API limit exceeded for 2021-07-01. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-07-01.
# API limit exceeded for 2021-07-01. Trying again in 15 seconds... Retry attempt: 3
# Trying again for 2021-07-01.
# API limit exceeded for 2021-07-01. Trying again in 20 seconds... Retry attempt: 4
# Trying again for 2021-07-01.
# API limit exceeded for 2021-07-01. Trying again in 25 seconds... Retry attempt: 5
# Trying again for 2021-07-01.
# API limit exceeded for 2021-07-01. Trying again in 30 seconds... Retry attempt: 6
# Trying again for 2021-07-01.
# API limit exceeded for 2021-07-02. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-07-02.
# API limit exceeded for 2021-07-02. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-07-02.
# API limit exceeded for 2021-07-03. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-07-03.
# API limit exceeded for 2021-07-04. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-07-04.
# API limit exceeded for 2021-07-04. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-07-04.
# API limit exceeded for 2021-07-05. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-07-05.
# API limit exceeded for 2021-07-05. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-07-05.
# API limit exceeded for 2021-07-06. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-07-06.
# API limit exceeded for 2021-07-06. Trying again in 10 seconds... Retry attempt: 2
# Trying again for 2021-07-06.
# API limit exceeded for 2021-07-07. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-07-07.
# API limit exceeded for 2021-07-08. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-07-08.
# API limit exceeded for 2021-07-16. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-07-16.
# API limit exceeded for 2021-07-22. Trying again in 5 seconds... Retry attempt: 1
# Trying again for 2021-07-22.
# Month 7 done. Please wait for the next month to start... Time: 3 mins
# Collecting data for Month 8...
# Month 8 done. Please wait for the next month to start... Time: 3 mins
# Collecting data for Month 9...
# Month 9 done. Please wait for the next month to start... Time: 3 mins
# Collecting data for Month 10...
# Month 10 done. Please wait for the next month to start... Time: 3 mins
# Collecting data for Month 11...
# Month 11 done. Please wait for the next month to start... Time: 3 mins
# Collecting data for Month 12...
# Month 12 done. Please wait for the next month to start... Time: 3 mins
# Data collection complete.
#        locationId                                     location parameter  \
# 0           65397                  Sansiri - d'Vieng Santitham      pm25
# 1           65176  Sansiri - Saransiri Tiwanon-Chaengwattana 2      pm25
# 2           69950                Sansiri - Siri Place Westgate      pm25
# 3           72114          Sansiri - The Base Height Udonthani      pm25
# 4           70059                        Sansiri - dcondo sign      pm25
# ...           ...                                          ...       ...
# 11699       72914        Sansiri - Setthasiri Charan Pinklao 2      pm25
# 11700       70066                         Sansiri - dcondo nim      pm25
# 11701       72911                 Sansiri - The Base Phetkasem      pm25
# 11702       65631                           E23BMY-Air-Station      pm25
# 11703      228773                                AQSEA_THA_012      pm25
#
#        value   unit country  city  isMobile isAnalysis     entity  \
# 0       69.7  µg/m³      TH  None     False      False  community
# 1      123.3  µg/m³      TH  None     False      False  community
# 2       77.6  µg/m³      TH  None     False      False  community
# 3      119.0  µg/m³      TH  None     False      False  community
# 4       57.4  µg/m³      TH  None     False      False  community
# ...      ...    ...     ...   ...       ...        ...        ...
# 11699   30.4  µg/m³      TH  None     False      False  community
# 11700   47.1  µg/m³      TH  None     False      False  community
# 11701   25.7  µg/m³      TH  None     False      False  community
# 11702    0.8  µg/m³      TH  None     False      False  community
# 11703   32.9  µg/m³      TH  None     False       None  community
#
#             sensorType                   date.utc                 date.local  \
# 0      low-cost sensor  2021-01-19T23:59:57+00:00  2021-01-20T06:59:57+07:00
# 1      low-cost sensor  2021-01-19T23:59:55+00:00  2021-01-20T06:59:55+07:00
# 2      low-cost sensor  2021-01-19T23:59:54+00:00  2021-01-20T06:59:54+07:00
# 3      low-cost sensor  2021-01-19T23:59:53+00:00  2021-01-20T06:59:53+07:00
# 4      low-cost sensor  2021-01-19T23:59:49+00:00  2021-01-20T06:59:49+07:00
# ...                ...                        ...                        ...
# 11699  low-cost sensor  2021-12-31T14:12:25+00:00  2021-12-31T21:12:25+07:00
# 11700  low-cost sensor  2021-12-31T14:11:57+00:00  2021-12-31T21:11:57+07:00
# 11701  low-cost sensor  2021-12-31T14:11:53+00:00  2021-12-31T21:11:53+07:00
# 11702  low-cost sensor  2021-12-31T14:11:48+00:00  2021-12-31T21:11:48+07:00
# 11703  low-cost sensor  2021-12-31T14:11:48+00:00  2021-12-31T21:11:48+07:00
#
#        coordinates.latitude  coordinates.longitude
# 0                 18.803404              98.982210
# 1                 13.961660             100.555150
# 2                 13.872132             100.387390
# 3                 17.411478             102.795340
# 4                 18.809105              99.015884
# ...                     ...                    ...
# 11699             13.767839             100.458540
# 11700             18.809770              99.015940
# 11701             13.715885             100.447395
# 11702             13.793413             100.570020
# 11703             18.794495             100.788445
#
# [4708143 rows x 15 columns]

# %%
# Save to CSV
openaq_df.to_csv('20220527_openaq_raw_data.csv', index=False)
print('Raw data saved as CSV.')
# Out:
# Raw data saved as CSV.
